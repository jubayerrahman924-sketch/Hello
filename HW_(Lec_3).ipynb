# %% [markdown]
# <a href="https://colab.research.google.com/github/jubayerrahman924-sketch/Hello/blob/main/HW_(Lec_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# HW 1
x = 10
y = 5
add = x + y
mul = x*y
sub = x - y
div = x/y
print("sum:", add)
print("product:", mul)
print("difference:", sub)
print("quotient:", div)
# Out:
# sum: 15
# product: 50
# difference: 5
# quotient: 2

# %%
# HW 2
id = "SM-ML-2025-B1-035"
name = "Md Jubayer Rahman"
batch = 1
hometown = "Kushtia"

print(id, "\t", name, "\t", batch, "\t", hometown)
# Out:
# SM-ML-2025-B1-035 	 Md Jubayer Rahman 	 1 	 Kushtia

# %%
# HW 3
x = 10
print("Before:", x)
x = 15
print ("After:", x)
# Out:
# Before: 10
# After: 15

# %%
#HW 4
x = "10"
y = "15"
print(int(x), int(y))
# Out:
# 10 15

# %%
#HW 5

number1 = int(input("Give first number: "))
number2 = int(input("Give second number: "))
number3 = int(input("Give third number: "))

sum = number1 + number2 + number3

average = sum/3

print(f"{average:.2f}")
# Out:
# Give first number: 15
# Give second number: 10
# Give third number: 3
# 9.33

# %%
#HW 6

number1 = int(input("Give your first number: "))

number2 = int(input("Give your second number: "))

operation = input("Which operation do you want to do? ")

add = number1 + number2

sub = number1 - number2

mul = number1 * number2

div = number1 / number2

if operation == "+":
  print(add)
elif operation == "-":
  print(sub)
elif operation == "*":
  print(mul)
elif operation == "/":
  print(div)
# Out:
# Give your first number: 15
# Give your second number: 10
# Which operation do you want to do? /
# 1.5

# %%
#HW 7

alphabet = input("Give your alphabet: ")

if alphabet == "a" or alphabet == "e" or alphabet == "i" or alphabet == "o" or alphabet == "u" or alphabet == "A" or alphabet == "E" or alphabet == "I" or alphabet == "O" or alphabet == "U":
 print("Vowel")
else:
 print("Consonant")
# Out:
# Give your alphabet: H
# Consonant

# %%
#HW 8
temp1 = input("Is your temperature in Celsius or Fahrenheit? ")
temp2 = int(input("Give your temperature:"))

Celsius = 5*(temp2-32)/9

Fahrenheit = 9*temp2/5+32

if temp1 == "Celsius":
  print(Fahrenheit)
if temp1 == "Fahrenheit":
  print(Celsius)
# Out:
# Is your temperature in Celsius or Fahrenheit? Celsius
# Give your temperature:-40
# -40.0

# %%
#HW 9

num1 = int(input("Give your first number:"))
num2 = int(input("Give your second number: "))
num3 = int(input("Give your third number: "))

if num1> num2 and num1>num3:
  print("The largest number is:", num1)
elif num2> num1 and num2>num3:
  print("The largest number is:", num2)
elif num3>num1 and num3>num2:
  print("The largest number is:", num3)
# Out:
# Give your first number:3
# Give your second number: 5
# Give your third number: 2
# The largest number is: 5

# %%
#HW 10

num = int(input("Give your number:"))

for x in range(1,num):
  if x%2 == 0:
    print(x)
# Out:
# Give your number:15
# 2
# 4
# 6
# 8
# 10
# 12
# 14

# %%
#HW 11

num = int(input("Give your number: "))

sum = 0

for x in range (1, num):
  if x%3 == 0 or x%5 == 0:
    sum = sum + x
    print(sum)
# Out:
# Give your number: 10
# 3
# 8
# 14
# 23

# %%
#HW 12

num = int(input("Give your number: "))

for x in range (1, num+1):
  product = num * x
  print(product)
# Out:
# Give your number: 12
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120
# 132
# 144
